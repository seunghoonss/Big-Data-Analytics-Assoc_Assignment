# %% [markdown]
# ### 반복문을 이용해서 여러가지 subplot을 만들어 주세요!!
# - 데이터는 타이타닉 데이터로 시각화 하기
#
# - 타이타닉데이터의 경우는 분석할 수 있는 변수간의 관계가 정말 많아요!
# - survived 이 변수에 따라서 달라지는 변수를 시각화 하는 것이 중요하다!
#
# - 최대한 모든 변수를 시각화 해주시고 시각화 한 내용에 대해서 주석처리 및 마크다운으로 인사이트 정리
# - 반복문을 이용해서 시각화를 진행해 주세요!
#
# - 과제기한 - 11.6
# - 수업 시작 11.6 (10월 한 달은 수업이 없음)

# %%
import pandas as pd # 판다스
import seaborn as sns # seaborn 
from matplotlib import pyplot as plt # matplotlib
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### 변수 pclass, sex, age, fare 시각화

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(15,10))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['pclass','sex','age','fare']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax)           # 그래프위 위치 결정
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 변수 sibsp, parch, embarked, class 시각화

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(15,10))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['sibsp','parch','embarked','class']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax)           # 그래프위 위치 결정
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 변수 who,	adult_male,	deck, embark_town 시각화

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(15,10))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['who','adult_male','deck','embark_town']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax)           # 그래프위 위치 결정
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 변수 deck,	embark_town,	alive,	alone 시각화

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(15,10))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['deck','embark_town','alive','alone']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax)           # 그래프위 위치 결정
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 변수 pclass,	sex,	age,	sibsp,	parch,	fare,	embarked,	class	시각화

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(4,4) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(35,20))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax)           # 그래프위 위치 결정
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 변수 who,	adult_male,	deck,	embark_town,	alive,	alone	시각화

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,3) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(35,20))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax)           # 그래프위 위치 결정
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### hue 변수 분리하지 않고 누적 그래프

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,3) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(35,20))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax,           # 그래프위 위치 결정
                 dodge=False)    # 누적 그래프     
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 그래프 변수를 y 축으로 세로로 변경

# %%
#gridspec 이 모듈을 가지고 온다!
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,3) #본인이 그리고 싶은 그래프의 개수를 적으면 됩니다.
plt.figure(figsize=(35,20))
plt.subplots_adjust(wspace=0.5, hspace=0.3) #현재 배치되어 있는 subplot들의 위치를 직접 조정한다
                                            # wspace 가로 간격, hspace 세로 간격

    
#서브플롯에 필요한 컬럼을 가져온다!
titanic_features = ['who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

for idx, feature in enumerate(titanic_features): # 인덱스(index)와 원소를 동시에 접근하면서 루프를 돌릴 수 있다.
    ax = plt.subplot(grid[idx])
    
    sns.countplot(y=feature,      # feature calss
                 data=titanic,    # data는 titanic 데이터
                 hue='survived',  # survived 컬럼의 값별로 count
                 palette='pastel',# 색 구성
                 ax=ax,           # 그래프위 위치 결정
                 dodge=False)    # 누적 그래프     
    ax.set_title(f'{feature} Distribution')

# %% [markdown]
# ### 수고하셨습니다 :)
